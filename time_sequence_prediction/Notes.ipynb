# %% [markdown]
# # 关于继承 super()
# http://www.srikanthtechnologies.com/blog/python/mro.aspx

# %% [markdown]
# ## Case 1

# %%
class A:
    def process(self):
        print("A process()")

# %%
class B:
    pass

# %%
class C(A, B):
    def foo(self):
        print(self)

# %%
obj = C()
obj.process()
obj.foo()
# see the Method Resolution Order(MRO)
print(C.mro()) # print MRO for class C
# Out:
# A process()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-40c4f107fc7b> in <module>
#       1 obj = C()
#       2 obj.process()
# ----> 3 obj.foo()
#       4 # see the Method Resolution Order(MRO)
#       5 print(C.mro()) # print MRO for class C
#
# TypeError: foo() takes 0 positional arguments but 1 was given

# %% [markdown]
# ## Case 2

# %%
class A:
    pass
#     def process(self):
#         print("A process()")

class B:
    def process(self):
        print("B process()")

class C(A, B):
    pass

obj = C()
obj.process()
# Out:
# B process()

# %% [markdown]
# ## case 3

# %%
class A:
    def process(self):
        print('A process()')

class B:
    def process(self):
        print('B process()')


class C(A, B):
    def process(self):
        print('C process()')

class D(C,B):
    pass


obj = D()
obj.process()

print(D.mro())
# Out:
# C process()
# [<class '__main__.D'>, <class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]

# %% [markdown]
# ## Case 4

# %%
class A:
    def process(self):
        print('A process()')
        print(self)

class B(A):
    pass

class C(A):
    pass
#     def process(self):
#         print('C process()')
#         print(self)

class D(B,C):
    pass


obj = D()
obj.process()
print(D.mro())
# Out:
# A process()
# <__main__.D object at 0x10dee9a50>
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %% [markdown]
# ## Case 5

# %%
class Base(object):
    def __init__(self):
        print("Base init'ed")

class ChildA(Base):
    def __init__(self):
        print("ChildA init'ed")
        Base.__init__(self)

class ChildB(Base):
    def __init__(self):
        print("ChildB init'ed")
        super(ChildB, self).__init__()

# %%
class UserDependency(Base):
    def __init__(self):
        print("UserDependency init'ed")
        super(UserDependency, self).__init__()

# %%
class UserDependency2(Base):
    def __init__(self):
        print("UserDependency2 init'ed")
        super(UserDependency2, self).__init__()

# %%
class UserA(ChildA, UserDependency):
    def __init__(self):
        print("UserA init'ed")
        # super(UserA, self).__init__()
        super().__init__()

class UserB(ChildB, UserDependency, UserDependency2):
    def __init__(self):
        print("UserB init'ed")
        super(UserB, self).__init__()
        #super(ChildB,self).__init__()
        # super().__init__()

# %%
UserA()
# Out:
# UserA init'ed
# ChildA init'ed
# Base init'ed

# %%
UserA.mro()
# Out:
# [__main__.UserA,
#  __main__.ChildA,
#  __main__.UserDependency,
#  __main__.Base,
#  object]

# %%
b = UserB()
# Out:
# UserB init'ed
# ChildB init'ed
# UserDependency init'ed
# UserDependency2 init'ed
# Base init'ed

# %%
UserB.mro()
# Out:
# [__main__.UserB,
#  __main__.ChildB,
#  __main__.UserDependency,
#  __main__.UserDependency2,
#  __main__.Base,
#  object]

# %% [markdown]
# ## super(class,self)解释 https://www.artima.com/weblogs/viewpost.jsp?thread=236278

# %%
class B1(object):
    def f(self):
        return 1
    def __repr__(self):
        return '<instance of %s>'%self.__class__.__name__

# %%
class C1(B1):
    pass

# %%
super(C1).f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7fa34ee828ba> in <module>
# ----> 1 super(C1).f
#
# AttributeError: 'super' object has no attribute 'f'

# %%
super(C1,C1).f
# Out:
# <function __main__.B1.f(self)>

# %%
print(super(C1).__repr__())
# Out:
# <super: <class 'C1'>, NULL>

# %%
print(super(C1, C1).__repr__)
# Out:
# <function B1.__repr__ at 0x103c0bc20>

# %%
# what's the use of super(C)

# %%
class B(object):
    a = 1

class C(B):
    pass

class D(C):
    sup = super(C)

# %%
d = D()

# %%
d.sup.a
# Out:
# 1
